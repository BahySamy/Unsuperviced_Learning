# %%
from plotnine import *
from sklearn.decomposition import PCA
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.datasets import load_breast_cancer
data = load_breast_cancer()
df = pd.DataFrame(data.data, columns=data.feature_names)
df['target'] = pd.Series(data.target)

# %%
print(df.columns)
df.head()
df.shape
# Out:
# Index(['mean radius', 'mean texture', 'mean perimeter', 'mean area',
#        'mean smoothness', 'mean compactness', 'mean concavity',
#        'mean concave points', 'mean symmetry', 'mean fractal dimension',
#        'radius error', 'texture error', 'perimeter error', 'area error',
#        'smoothness error', 'compactness error', 'concavity error',
#        'concave points error', 'symmetry error', 'fractal dimension error',
#        'worst radius', 'worst texture', 'worst perimeter', 'worst area',
#        'worst smoothness', 'worst compactness', 'worst concavity',
#        'worst concave points', 'worst symmetry', 'worst fractal dimension',
#        'target'],
#       dtype='object')
# (569, 31)

# %%
features = df.columns[0:30] #grab all numeric columns of interest
z = StandardScaler()
df[features] = z.fit_transform(df[features])

# %%
ggplot(df, aes(x = "mean radius", y = "mean texture")) + geom_point()
# Out:
# <ggplot: (160523503550)>

# %%
pca = PCA()
pca.fit(df[features])
pca.explained_variance_ratio_
# Out:
# array([4.42720256e-01, 1.89711820e-01, 9.39316326e-02, 6.60213492e-02,
#        5.49576849e-02, 4.02452204e-02, 2.25073371e-02, 1.58872380e-02,
#        1.38964937e-02, 1.16897819e-02, 9.79718988e-03, 8.70537901e-03,
#        8.04524987e-03, 5.23365745e-03, 3.13783217e-03, 2.66209337e-03,
#        1.97996793e-03, 1.75395945e-03, 1.64925306e-03, 1.03864675e-03,
#        9.99096464e-04, 9.14646751e-04, 8.11361259e-04, 6.01833567e-04,
#        5.16042379e-04, 2.72587995e-04, 2.30015463e-04, 5.29779290e-05,
#        2.49601032e-05, 4.43482743e-06])

# %%
pcaDF = pd.DataFrame({"pc": range(1,31),"expl_var" : pca.explained_variance_ratio_,  "cum_var": pca.explained_variance_ratio_.cumsum()})
pcaDF.head()
# Out:
#    pc  expl_var   cum_var
# 0   1  0.442720  0.442720
# 1   2  0.189712  0.632432
# 2   3  0.093932  0.726364
# 3   4  0.066021  0.792385
# 4   5  0.054958  0.847343

# %%
(ggplot(pcaDF, aes(x = "pc", y = "expl_var")) + geom_line() + geom_point())
# Out:
# <ggplot: (143510922963)>

# %%
(ggplot(pcaDF, aes(x = "pc", y = "cum_var")) + geom_line(color = "pink") +
 geom_point(color = "pink") + geom_hline(yintercept = 0.95))
# Out:
# <ggplot: (143510760894)>

# %%
data = pca.transform(df[features])
df4 = pd.DataFrame(data[:,0:4])


df10 = pd.DataFrame(data[:, 0:10])

#modeMod1
lr1 = LogisticRegression()
lr1.fit(df[features], df["target"])
print("all data: ", lr1.score(df[features], df["target"]))

#modeMod1
lr2 = LogisticRegression()
lr2.fit(df10, df["target"])
print("10 PCs:   ", lr2.score(df10, df["target"]))

#modeMod1
lr3 = LogisticRegression()
lr3.fit(df4, df["target"])
print("4 PCs:    ", lr3.score(df4, df["target"]))
# Out:
# all data:  0.9876977152899824
# 10 PCs:    0.9859402460456942
# 4 PCs:     0.9701230228471002

# %% [markdown]
# ## My Data

# %%
my_data = pd.read_csv('D:\ITI\Courses\machune_learning_2\Day_2\heart.csv')
print('data shape is: ', my_data.shape)
my_data.head()
# Out:
# data shape is:  (303, 14)
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
df = my_data.drop(['target'], axis = 1)
df.sample(4)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 110   64    0   0       180   325    0        1      154      1      0.0
# 261   52    1   0       112   230    0        1      160      0      0.0
# 2     41    0   1       130   204    0        0      172      0      1.4
# 255   45    1   0       142   309    0        0      147      1      0.0
#
#      slope  ca  thal
# 110      2   0     2
# 261      2   1     2
# 2        2   0     2
# 255      1   3     3

# %%
z = StandardScaler()
df_standarized = pd.DataFrame(z.fit_transform(df))

# %%
df_standarized.columns = df.columns
df_standarized.head()
# Out:
#         age       sex        cp  trestbps      chol       fbs   restecg  \
# 0  0.952197  0.681005  1.973123  0.763956 -0.256334  2.394438 -1.005832
# 1 -1.915313  0.681005  1.002577 -0.092738  0.072199 -0.417635  0.898962
# 2 -1.474158 -1.468418  0.032031 -0.092738 -0.816773 -0.417635 -1.005832
# 3  0.180175  0.681005  0.032031 -0.663867 -0.198357 -0.417635  0.898962
# 4  0.290464 -1.468418 -0.938515 -0.663867  2.082050 -0.417635  0.898962
#
#     thalach     exang   oldpeak     slope        ca      thal
# 0  0.015443 -0.696631  1.087338 -2.274579 -0.714429 -2.148873
# 1  1.633471 -0.696631  2.122573 -2.274579 -0.714429 -0.512922
# 2  0.977514 -0.696631  0.310912  0.976352 -0.714429 -0.512922
# 3  1.239897 -0.696631 -0.206705  0.976352 -0.714429 -0.512922
# 4  0.583939  1.435481 -0.379244  0.976352 -0.714429 -0.512922

# %%
# correlation matrix and heatmap to stand on important features
corr_matrix = df_standarized.corr()
mask = np.triu(np.ones_like(corr_matrix,dtype = bool))
plt.figure(figsize = (20,10))
sns.heatmap(corr_matrix, fmt = '0.2f', cmap = 'Blues', mask = mask, annot = True)
plt.title("Correlation Analysis");

# %%
pca = PCA()
pca.fit(df_standarized)
pca.explained_variance_ratio_
# Out:
# array([0.21254053, 0.11820708, 0.09406418, 0.09085735, 0.07861281,
#        0.07461661, 0.06636692, 0.05968811, 0.05530196, 0.04781309,
#        0.04077729, 0.03254941, 0.02860467])

# %%
pcaDF = pd.DataFrame({"pc": range(1,14),"expl_var" : pca.explained_variance_ratio_,  "cum_var": pca.explained_variance_ratio_.cumsum()})
pcaDF.head()
# Out:
#    pc  expl_var   cum_var
# 0   1  0.212541  0.212541
# 1   2  0.118207  0.330748
# 2   3  0.094064  0.424812
# 3   4  0.090857  0.515669
# 4   5  0.078613  0.594282

# %%
(ggplot(pcaDF, aes(x = "pc", y = "expl_var")) + geom_line() + geom_point())
# Out:
# <ggplot: (73410034134)>

# %%
(ggplot(pcaDF, aes(x = "pc", y = "cum_var")) + geom_line(color = "pink") +
 geom_point(color = "pink") + geom_hline(yintercept = 0.95))
# Out:
# <ggplot: (73411222676)>

# %%
features = pca.transform(df_standarized)
df4 = pd.DataFrame(features[:,0:4])


df9 = pd.DataFrame(features[:, 0:9])

#modeMod1
lr1 = LogisticRegression()
lr1.fit(features, my_data["target"])
print("all data: ", lr1.score(features, my_data["target"]))

#modeMod1
lr2 = LogisticRegression()
lr2.fit(df9, my_data["target"])
print("9 PCs:   ", lr2.score(df9, my_data["target"]))

#modeMod1
lr3 = LogisticRegression()
lr3.fit(df4, my_data["target"])
print("4 PCs:    ", lr3.score(df4, my_data["target"]))
# Out:
# all data:  0.8514851485148515
# 9 PCs:    0.858085808580858
# 4 PCs:     0.8415841584158416
